# %%
import glob
import pandas as pd
import bs4 as bs
from bs4 import BeautifulSoup
import lxml as lx
from bs4 import NavigableString

#ETL of original xml files into pandas DataFrames.

# %%
xml_filenames=glob.glob("*.xml")
df=pd.DataFrame(xml_filenames,columns=['xml_filenames'])

strings=[]
notBefore=[]
notAfter=[]

for filenm in xml_filenames:
    infile = open(filenm,"r")
    contents = infile.read()
    soup = BeautifulSoup(contents, "xml")

    
    #get strings
    
    edition=soup.find(type='edition')
    
    if edition is None:
        strings.append("no value") #no text; these are often drawings 
        print(filenm, ' found no text')
    elif 'lang' not in edition.attrs: #no greek text
        strings.append("no value")
        print(filenm, ' found no lang')
    elif edition['lang']=='la': #is latin
        strings.append("no value")
        print(filenm, ' inscription is latin')

    else:
        this_string=""
        text=edition.find_all(['ab','lg'])
        for section in text:
            for child in section.descendants:
                if child.parent.name == "note" or child.name=="note": #omit english notes
                    continue
                elif child.name=="gap": #include original word spacing
                    this_string=this_string+" "
                elif type(child) is NavigableString and child.string is not None: #omit usage error
                    if child.string != "No text" or "o text":
                        this_string=this_string+child.string
        if this_string is not "":
            strings.append(this_string)
        else:
            strings.append("no value")
            print(filenm, ' found no text')
            
            
    #get date info
    
    dsoup=soup.find(n="date")

    #earliest possible date of inscription
    tag=dsoup.find(notBefore=True)
    if tag is None:
        notBefore.append('no value')
    else:
        notBefore.append(tag.get('notBefore'))

    #latest possible date 
    tag=dsoup.find(notAfter=True)
    if tag is None:
        notAfter.append('no value')
    else:
        notAfter.append(tag.get('notAfter'))

        
#takes about 20s on home computer
# Out:
# iAph120315.xml  found no text
# iAph020011.xml  found no text
# iAph150225.xml  found no text
# iAph100009.xml  found no text
# iAph100022.xml  found no text
# iAph100005.xml  found no text
# iAph020012.xml  found no text
# iAph080062.xml  found no text
# iAph020524.xml  inscription is latin
# iAph100019.xml  found no text
# iAph110210.xml  found no text
# iAph010401.xml  found no text
# iAph010201.xml  inscription is latin
# iAph100023.xml  found no text
# iAph100020.xml  found no text
# iAph100018.xml  found no text
# iAph040304.xml  inscription is latin
# iAph080093.xml  found no text
# iAph110063.xml  inscription is latin
# iAph040005.xml  found no text
# iAph080401.xml  found no text
# iAph100008.xml  found no text
# iAph080091.xml  found no text
# iAph100016.xml  found no text
# iAph140005.xml  found no lang
# iAph090115.xml  found no text
# iAph110201.xml  found no text
# iAph080601.xml  found no text
# iAph080053.xml  found no text
# iAph040002.xml  found no text
# iAph050001.xml  found no text
# iAph060003.xml  found no text
# iAph020401.xml  found no text
# iAph120530.xml  found no text

# %%
df['string']=strings
df['date_notBefore']=notBefore
df['date_notAfter']=notAfter
df=df[df['string']!="no value"]

df.set_value(938,'date_notAfter','0225') #fixing a typo specific to this set

df.to_csv('collected_inscription_data.csv')

# %%
df[df['xml_filenames']=='iAph010003.xml']
#test for inclusion of strings from all ab sections in "type='edition'"
#(010003 has two,separated by a period)
# Out:
#       xml_filenames                             string date_notBefore  \
# 463  iAph010003.xml  λαιιβ οἱ οἰκοδόμοι. ἐπιμεληθέντος           0001
#
#     date_notAfter
# 463          1000

# %%
df[df['xml_filenames']=='iAph080270.xml']
#no ab section. extensive grk text in 'lg'. confirming the greek text is loaded
# Out:
#      xml_filenames                                             string  \
# 88  iAph080270.xml  \n\n τύμβος Ἰορδά\nνοιο τὸν Εὐλαλί\nου ἀπὸ φύτ...
#
#    date_notBefore date_notAfter
# 88           0401          0600

# %%
df[df['xml_filenames']=='iAph100006.xml']
#both greek and english sections in 'edition'. test for exclusion of english text nested in 'note' sections.
# Out:
#       xml_filenames                                             string  \
# 374  iAph100006.xml   μοστρατου\n   \nΒ\nΙ\nΟ\nΙ\nΛ  σιέων \n\nἈπολ...
#
#     date_notBefore date_notAfter
# 374           0101          0500

# %%
#saving data in this intermediate form for use as needed:


#separating out undated inscriptions for later use
undated=df[(df['date_notAfter']=="no value")|(df['date_notBefore']=="no value")]
undated.to_csv('undated_inscriptions.csv')


#removing undated inscriptions from set in current use; converting dates to numeric value
#for sorting
dated=df[(df['date_notAfter']!="no value")&(df['date_notBefore']!="no value")]
dated['date_notBefore']=pd.to_numeric(dated['date_notBefore'])
dated['date_notAfter']=pd.to_numeric(dated['date_notAfter'])


#separating out inscriptions with a possible date range greater than 100yrs
weakly_dated=dated[dated['date_notAfter']-dated['date_notBefore']>100]
dated=dated[dated['date_notAfter']-dated['date_notBefore']<100]


#saving all sets
weakly_dated.to_csv('weakly_dated_inscriptions.csv')
dated.to_csv('dated_inscriptions.csv')
# Out:
# /home/e/.local/lib/python3.5/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /home/e/.local/lib/python3.5/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
#the data currently loaded:
dated
# Out:
#        xml_filenames                                             string  \
# 4     iAph080216.xml                                              ΛΗΣ
# 5     iAph110065.xml     ἕτερος δὲ οὐδεὶς ἕξει ἐξουσίαν ἐνθάψε τινὰ ...
# 6     iAph090039.xml          Ἰουλίαν Σεβαστὴν Σεβαστοῦ θυγατέρα  Ἥραν
# 15    iAph010189.xml  ἡ πόλις ον Λικίννιον Οὐαλεριανὸν υἱὸν καὶ ἀδελ...
# 19    iAph080604.xml                                     τοῦτο\n νικᾳ.
# 22    iAph120511.xml                                           ἡ βουλή
# 24    iAph110057.xml      τὸν ἀξιολογώτατον  πρῶτον ἄρχοντα δὶς  ταμ...
# 25    iAph050119.xml              \n  Παλλάδιος  ἐ \nποίει καὶ ἀνέθηκεν
# 26    iAph120706.xml  \nἡ βουλὴ καὶ ὁ δῆμος ἐτείμησαν\n ταῖς καλλίστ...
# 34    iAph150315.xml     οὐδεὶς δὲ ἕτερος ἕξει ἐξουσίαν ἐνθαψαι τινα...
# 36    iAph080084.xml   ἡ βουλὴ καὶ ὁ δῆμος καὶ ἡ
# 1440  iAph090006.xml                                             Ἡμέρα
# 1443  iAph010008.xml  Ἄτταλος Μενάνδρου τοῦ Ἀττάλου καὶ Ἀτταλὶς Μενε...
# 1449  iAph010155.xml                                              π μ
# 1452  iAph080003.xml  ἔδοξεν τῇ βουλῇ καὶ τῷ δήμῳ  καὶ Περείτου του ...
# 1456  iAph150364.xml  ἡ βουλὴ ἐτείμησεν Μεν ανδρον    ΤΟΥ   Μ   υἱὸν...
# 1464  iAph080243.xml   Δ   ΙΑΣ  Ὑψικλίδης   Αυρηλίας Ἰουλίας Ἀπφίας ...
# 1467  iAph040302.xml      Μηνόδοτος    μάχου τοῦ Μηνοδότου  ἐποίει
# 1470  iAph150345.xml  \n Ἡ σορὸς καὶ ὁ περικίμε\n\t\t\tνος τόπος τού...
# 1473  iAph120026.xml     Ἄτταλος Ἀδράστου τοῦ Νεικοτίμου τοῦ  Ἀρ τεμ...
# 1476  iAph010182.xml    ἡ βουλὴ καὶ ὁ δῆμος καὶ ἡ\n\nγερουσία ἐτείμη...
# 1477  iAph080086.xml   κατὰ τὴν Ἰουνίου Μαξίμου τοῦ κρατίστου ταμίου...
# 1480  iAph130003.xml  ἡ σορὸς    ἐστὶνἈντιόχου ἐν ᾗ σορῷ κηδευθήσοντ...
# 1487  iAph090035.xml                                  Αἰνήαν   Ἀνχίσου
# 1489  iAph140015.xml  \n ἡ σορός ἐστιν\n ος αβλο \n β τοῦ Χρή\nστου ...
# 1490  iAph140004.xml   ἡ σορός ἐστὶν Αἰμιλίας Μελτίνης τῆς Ἀλεξάνδρο...
# 1496  iAph121002.xml   ἡ βουλὴ καὶ ἡ γερουσία καὶ ὁ σύνπας δῆμος  Δι...
# 1500  iAph040301.xml                           πολέμωι υ   ι χαλκ
# 1504  iAph150343.xml                                             ΑΜΩ
#
#       date_notBefore  date_notAfter
# 4                  1            100
# 5                301            400
# 6                 14             69
# 15               253            260
# 19               301            400
# 22                 1            100
# 24               212            300
# 25               301            350
# 26                34             67
# 34               101            200
# 36               139            161
# 37               241            241
# 44               101            200
# 46               102            116
# 49                69             96
# 50                 1            100
# 51                 1            100
# 54                 1            100
# 55                 1            100
# 56               -33             33
# 60               201            300
# 67               201            250
# 68               101            150
# 69                14             69
# 71               301            400
# 72                 1            100
# 76               200            250
# 78               201            300
# 79                14             29
# 80                66            133
# ...              ...            ...
# 1408              14             69
# 1418               1            100
# 1421               1            100
# 1425             185            195
# 1426             200            250
# 1427            -200           -101
# 1430             101            200
# 1431             100            133
# 1432            -100             -1
# 1434               1            100
# 1437               1            100
# 1439              14             70
# 1440               1            100
# 1443              34             66
# 1449             101            200
# 1452             -88            -88
# 1456             230            240
# 1464             101            200
# 1467               1            100
# 1470             268            333
# 1473             117            138
# 1476             201            233
# 1477             167            168
# 1480             101            200
# 1487              14             69
# 1489             251            300
# 1490               0              0
# 1496             -33            -33
# 1500               1            100
# 1241  iAph130110.xml   ἡ σορὸς καὶ αἱ ὑποκείμεναι εἰσωσται εἰσιν Μάρ...
# 1267  iAph120716.xml    ἡ βουλὴ καὶ ὁ δῆμος ἐτείμησαν Τιβέριον Κλαύδ...
# 1287  iAph121112.xml    ζῆ   ὁ βωμὸς καὶ ἡ σορός ἐστιν Οὐλπίου  Κλαυ...
# 1327  iAph020503.xml    ἔδοξεν τῷ κοινῷ γνώμη προέδρων καὶ γραματέως...
# 1332  iAph120538.xml  \nἈγαθῇ Τύχῃ \nΜᾶρκος Οὔλπιος Ἀππουλήϊος Εὐρυκ...
# 1345  iAph130006.xml   ἡ βουλὴ καὶ ὁ δῆμος καὶ ἡ γερουσία ἐτείμησαν ...
# 1390  iAph130154.xml     ἐν ᾗ κεκήδευται αὐτὸς ὁΜένιππος καὶ κηδευθή...
# 1418  iAph120803.xml   ἐπὶ Ζήνωνος τοῦ Ὑψικλέους  εἰσηγησαμένου Ἑρμᾶ...
# 1452  iAph080003.xml  ἔδοξεν τῇ βουλῇ καὶ τῷ δήμῳ  καὶ Περείτου του ...
# 1456  iAph150364.xml  ἡ βουλὴ ἐτείμησεν Μεν ανδρον    ΤΟΥ   Μ   υἱὸν...
# 1473  iAph120026.xml     Ἄτταλος Ἀδράστου τοῦ Νεικοτίμου τοῦ  Ἀρ τεμ...
# 1476  iAph010182.xml    ἡ βουλὴ καὶ ὁ δῆμος καὶ ἡ\n\nγερουσία ἐτείμη...
# 1480  iAph130003.xml  ἡ σορὸς    ἐστὶνἈντιόχου ἐν ᾗ σορῷ κηδευθήσοντ...
# 1496  iAph121002.xml   ἡ βουλὴ καὶ ἡ γερουσία καὶ ὁ σύνπας δῆμος  Δι...
#
#       date_notBefore  date_notAfter
# 37               241            241
# 44               101            200
# 60               201            300
# 93               101            199
# 96               138            169
# 120              168            233
# 128              151            200
# 162              168            250
# 175              238            244
# 178              101            200
# 180                1            100
# 203              239            239
# 215              250            251
# 219              201            250
# 231              501            600
# 239              201            250
# 255              212            250
# 267               34            100
# 305              101            200
# 314             -200           -101
# 339              211            250
# 353              240            300
# 367              180            190
# 375              -80            -10
# 397              301            400
# 406              201            250
# 414              226            250
# 419                1            100
# 451              117            138
# 471                1            100
# ...              ...            ...
# 910               81             96
# 930              234            300
# 934              212            300
# 938              200            225
# 964              117            138
# 972              119            125
# 1007             -66           -200
# 1009               1            100
# 1026             224            224
# 1073              98            117
# 1083             117            138
# 1086             201            233
# 1097             401            450
# 1137             -85            -85
# 1197             226            250
# 1198            -100             -1
# 1241             201            250
# 1267             117            138
# 1287             167            233
# 1327            -100             -1
# 1332             180            189
# 1345             167            233
# 1390             234            267
# 1418               1            100
# 1452             -88            -88
# 1456             230            240
# 1473             117            138
# 1476             201            233
# 1480             101            200
# 1496             -33            -33
#
# [80 rows x 4 columns]
